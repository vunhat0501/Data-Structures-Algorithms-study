# %% [markdown]
# # Sorting algorithm

# %% [markdown]
# ## Sắp xếp đơn giản
# ### Đặc trưng
# - Ý tưởng dễ hiểu
# - cài đặt đơn giản
# - độ phức tạp cao
#
# ### Một số thuật toán sắp xếp đơn giản
# - kiểu lựa chọn (Selection sort)
# - kiểu chèn (Insertion sort)
# - kiểu nổi bọt (Bubble sort)
